# %%
import json
import pymongo
import pandas as pd
pymongo.MongoClient

#code to remove $ from file as this parameter causes issues when inserting into mongodb
with open("nyt2.json", errors='ignore') as fileOpener:
    file_data=fileOpener.read()

file_data=file_data.replace("$","")
#writing to a new file

with open("movies_data_short_corrected.json","w+" ) as fileWriter:
    fileWriter.write(file_data)

#inserting data into MongoDb
client = pymongo.MongoClient(host="localhost", port=27017)
db = client.Mylib
collection = db.books
data = pd.DataFrame(list(collection.find()))
#print(file_data)
data = [json.loads(line) for line in open("movies_data_short_corrected.json", 'r')]
#print(data)
for row in data:
    x = collection.insert_one(row)
      
print('Data inserted sucessfully')
# Out:
# Data inserted sucessfully

# %%
import pymongo
import pandas as pd
from pymongo import MongoClient
client = MongoClient(host="localhost", port=27017)
db = client.Mylib
collection = db.books
data = pd.DataFrame(list(collection.find()))
data.head()
# Out:
#                                    _id  \
# 0  {'oid': '5b4aa4ead3089013507db18b'}
# 1  {'oid': '5b4aa4ead3089013507db18c'}
# 2  {'oid': '5b4aa4ead3089013507db18d'}
# 3  {'oid': '5b4aa4ead3089013507db18e'}
# 4  {'oid': '5b4aa4ead3089013507db18f'}
#
#                             bestsellers_date  \
# 0  {'date': {'numberLong': '1211587200000'}}
# 1  {'date': {'numberLong': '1211587200000'}}
# 2  {'date': {'numberLong': '1211587200000'}}
# 3  {'date': {'numberLong': '1211587200000'}}
# 4  {'date': {'numberLong': '1211587200000'}}
#
#                               published_date  \
# 0  {'date': {'numberLong': '1212883200000'}}
# 1  {'date': {'numberLong': '1212883200000'}}
# 2  {'date': {'numberLong': '1212883200000'}}
# 3  {'date': {'numberLong': '1212883200000'}}
# 4  {'date': {'numberLong': '1212883200000'}}
#
#                                   amazon_product_url             author  \
# 0  http://www.amazon.com/Odd-Hours-Dean-Koontz/dp...      Dean R Koontz
# ...

# %%
data
# Out:
#                                        _id  \
# 0      {'oid': '5b4aa4ead3089013507db18b'}
# 1      {'oid': '5b4aa4ead3089013507db18c'}
# 2      {'oid': '5b4aa4ead3089013507db18d'}
# 3      {'oid': '5b4aa4ead3089013507db18e'}
# 4      {'oid': '5b4aa4ead3089013507db18f'}
# ...                                    ...
# 10190  {'oid': '5b4aa4ead3089013507dd959'}
# 10191  {'oid': '5b4aa4ead3089013507dd95a'}
# 10192  {'oid': '5b4aa4ead3089013507dd95b'}
# 10193  {'oid': '5b4aa4ead3089013507dd95c'}
# 10194  {'oid': '5b4aa4ead3089013507dd95d'}
#
#                                 bestsellers_date  \
# 0      {'date': {'numberLong': '1211587200000'}}
# 1      {'date': {'numberLong': '1211587200000'}}
# 2      {'date': {'numberLong': '1211587200000'}}
# 3      {'date': {'numberLong': '1211587200000'}}
# 4      {'date': {'numberLong': '1211587200000'}}
# ...                                          ...
# 10190  {'date': {'numberLong': '1530921600000'}}
# ...

# %%
import pandas as pd
import re
import string
string.ascii_lowercase
import datetime

# %%
data = pd.read_json('C:/Users/Javed Mohammed/Downloads/nyt2.json', lines=True, orient='columns')
data.head()
# Out:
#                                     _id  \
# 0  {'$oid': '5b4aa4ead3089013507db18b'}
# 1  {'$oid': '5b4aa4ead3089013507db18c'}
# 2  {'$oid': '5b4aa4ead3089013507db18d'}
# 3  {'$oid': '5b4aa4ead3089013507db18e'}
# 4  {'$oid': '5b4aa4ead3089013507db18f'}
#
#                               bestsellers_date  \
# 0  {'$date': {'$numberLong': '1211587200000'}}
# 1  {'$date': {'$numberLong': '1211587200000'}}
# 2  {'$date': {'$numberLong': '1211587200000'}}
# 3  {'$date': {'$numberLong': '1211587200000'}}
# 4  {'$date': {'$numberLong': '1211587200000'}}
#
#                                 published_date  \
# 0  {'$date': {'$numberLong': '1212883200000'}}
# 1  {'$date': {'$numberLong': '1212883200000'}}
# 2  {'$date': {'$numberLong': '1212883200000'}}
# 3  {'$date': {'$numberLong': '1212883200000'}}
# 4  {'$date': {'$numberLong': '1212883200000'}}
#
#                                   amazon_product_url             author  \
# ...

# %%
data=data.drop(['_id'], axis=1)

# %%
data=data.drop(['bestsellers_date'], axis=1)

# %%
data=data.drop(['amazon_product_url'], axis=1)

# %%
data
# Out:
#                                     published_date              author  \
# 0      {'$date': {'$numberLong': '1212883200000'}}       Dean R Koontz
# 1      {'$date': {'$numberLong': '1212883200000'}}     Stephenie Meyer
# 2      {'$date': {'$numberLong': '1212883200000'}}        Emily Giffin
# 3      {'$date': {'$numberLong': '1212883200000'}}   Patricia Cornwell
# 4      {'$date': {'$numberLong': '1212883200000'}}     Chuck Palahniuk
# ...                                            ...                 ...
# 10190  {'$date': {'$numberLong': '1532217600000'}}          Mike Maden
# 10191  {'$date': {'$numberLong': '1532217600000'}}  Catherine Steadman
# 10192  {'$date': {'$numberLong': '1532217600000'}}          Celeste Ng
# 10193  {'$date': {'$numberLong': '1532217600000'}}        Nora Roberts
# 10194  {'$date': {'$numberLong': '1532217600000'}}         Riley Sager
#
#                                              description  \
# ...

# %%
import re
regex = re.compile('[^a-z0-9]')

#convert string to lowercase and replace all non alphanumeric characters
def set_lc_values(col_name):
    new_values = []
    for values in raw_books[col_name]:
        new_values.append(regex.sub('', values.lower()))

    return new_values



def flatten_json(y):
    # extract values from json string in dataframe
    
    out = {}
    ret_val = '-'
    
    def flatten(x, name=''):
        if type(x) is dict:
            for a in x:
                flatten(x[a], name + a + '_')
        elif type(x) is list:
            i = 0
            for a in x:
                flatten(a, name + str(i) + '_')
                i += 1
        elif type(x) is str:
            out[name[:-1]] = x


    flatten(y)

    if type(out) is dict:
        for v in out:
            ret_val = out[v]
    
    return ret_val

# %%
from string import ascii_lowercase
from datetime import datetime
for i in range(len(data)):
    data.loc[i]["price"] = flatten_json(data.loc[i]["price"])
    data.loc[i]["published_date"] = datetime.fromtimestamp(int(flatten_json(data.loc[i]["published_date"])[:10])).strftime('%Y-%m-%d')
    data.loc[i]["rank"] = flatten_json(data.loc[i]["rank"])
    data.loc[i]["rank_last_week"] = flatten_json(data.loc[i]["rank_last_week"])
    data.loc[i]["title"] = flatten_json(data.loc[i]["title"]) 
    data.loc[i]["weeks_on_list"] = flatten_json(data.loc[i]["weeks_on_list"])     
    
data.head()
# Out:
#   published_date             author  \
# 0     2008-06-08      Dean R Koontz
# 1     2008-06-08    Stephenie Meyer
# 2     2008-06-08       Emily Giffin
# 3     2008-06-08  Patricia Cornwell
# 4     2008-06-08    Chuck Palahniuk
#
#                                          description  price      publisher  \
# 0  Odd Thomas, who can communicate with the dead,...     27         Bantam
# 1  Aliens have taken control of the minds and bod...  25.99  Little, Brown
# 2  A woman's happy marriage is shaken when she en...  24.95   St. Martin's
# 3  A Massachusetts state investigator and his tea...  22.95         Putnam
# 4  An aging porn queens aims to cap her career by...  24.95      Doubleday
#
#                       title rank rank_last_week weeks_on_list
# 0                 ODD HOURS    1              0             1
# 1                  THE HOST    2              1             3
# 2  LOVE THE ONE YOU'RE WITH    3              2             2
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10195 entries, 0 to 10194
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   published_date  10195 non-null  object
#  1   author          10195 non-null  object
#  2   description     10195 non-null  object
#  3   price           10195 non-null  object
#  4   publisher       10195 non-null  object
#  5   title           10195 non-null  object
#  6   rank            10195 non-null  object
#  7   rank_last_week  10195 non-null  object
#  8   weeks_on_list   10195 non-null  object
# dtypes: object(9)
# memory usage: 717.0+ KB

# %%
# !pip install psycopg2
from sqlalchemy import create_engine
engine = create_engine('postgresql://postgres:Vishal*123#@dbinstance.cqxhwouf8ikq.eu-west-1.rds.amazonaws.com:3011/db_DAP')
data.to_sql('Books_Data', engine)

# %%
data['published_date'] = pd.to_datetime(data['published_date'])

# %%
data['published_date'] = data.published_date.dt.year

# %%
data
# Out:
#        published_date              author  \
# 0                2008       Dean R Koontz
# 1                2008     Stephenie Meyer
# 2                2008        Emily Giffin
# 3                2008   Patricia Cornwell
# 4                2008     Chuck Palahniuk
# ...               ...                 ...
# 10190            2018          Mike Maden
# 10191            2018  Catherine Steadman
# 10192            2018          Celeste Ng
# 10193            2018        Nora Roberts
# 10194            2018         Riley Sager
#
#                                              description  price  \
# 0      Odd Thomas, who can communicate with the dead,...     27
# 1      Aliens have taken control of the minds and bod...  25.99
# 2      A woman's happy marriage is shaken when she en...  24.95
# 3      A Massachusetts state investigator and his tea...  22.95
# 4      An aging porn queens aims to cap her career by...  24.95
# ...                                                  ...    ...
# ...

# %%
data.sort_values(by= 'price', inplace=True)
df = data[['author','title']].groupby(pd.Grouper(key='author'),as_index=False).count()
df
# Out:
#                                    author  title
# 0                              Donna Leon     13
# 1    Mary Higgins Clark and Alafair Burke     15
# 2                         Lisa Scottoline     47
# 3                             Ken Follett     67
# 4                      Richard Paul Evans     44
# ..                                    ...    ...
# 733                  David Foster Wallace      4
# 734       Tom Clancy with Grant Blackwood     13
# 735  Michael Crichton and Richard Preston      6
# 736                           Jean M Auel     11
# 737                           J K Rowling     15
#
# [738 rows x 2 columns]

# %%
df.sort_values(by= 'title', inplace=True, ascending=False)
df
# Out:
#               author  title
# 12      John Grisham    226
# 13    David Baldacci    222
# 38    Danielle Steel    174
# 14      Stephen King    157
# 21     Anthony Doerr    141
# ..               ...    ...
# 453  Karen Cleveland      1
# 452   Naomi Alderman      1
# 451  various authors      1
# 633    Chang-Rae Lee      1
# 526      Reif Larsen      1
#
# [738 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import rcParams
import seaborn as sns
from scipy.stats import skew
plot1=df.head(20)
rcParams['figure.dpi']=300
plt.style.use('seaborn-whitegrid')
sns.barplot(data=plot1,x='title',y='author',orient='h',palette='rainbow_r')
# Out:
# <AxesSubplot:xlabel='title', ylabel='author'>

# %%
df1 = data[['price','title']].groupby(pd.Grouper(key='title'),as_index=False).count()
df1
# Out:
#                           title  price
# 0                THE GOLDEN EGG      2
# 1         THE CINDERELLA MURDER      6
# 2                      BETRAYED      1
# 3              EDGE OF ETERNITY     16
# 4         THE MISTLETOE PROMISE      5
# ...                         ...    ...
# 2295  AGAINST ALL THINGS ENDING      1
# 2296  THE LAND OF PAINTED CAVES     11
# 2297                   NEW YORK      1
# 2298                     REAMDE      2
# 2299         THE CASUAL VACANCY     15
#
# [2300 rows x 2 columns]

# %%
plot2 = df1.head(20)
plot2.plot(kind="hist",x='title',y='price')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df2 = data[['weeks_on_list','title']].groupby(pd.Grouper(key='weeks_on_list'),as_index=False).count()
df2
# Out:
#     weeks_on_list  title
# 0               0   1965
# 1               2   1335
# 2               1   2032
# 3              11    101
# 4              53     10
# ..            ...    ...
# 130           119      1
# 131           114      1
# 132           113      1
# 133           116      1
# 134           115      1
#
# [135 rows x 2 columns]

# %%
df2.sort_values(by= 'weeks_on_list', inplace=True, ascending=True)

# %%
plot3 = df2.head(20)
plot3.plot(kind="bar",x='weeks_on_list',y='title')
# Out:
# <AxesSubplot:xlabel='weeks_on_list'>
