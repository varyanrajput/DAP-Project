# %%
import json
import requests
import pymongo

gnr = {28: 'Action', 12: 'Adventure', 16: 'Animation', 35: 'Comedy', 80: 'Crime', 99: 'Documentary', 18: 'Drama', 10751: 'Family', 14: 'Fantasy', 36: 'History', 27: 'Horror', 10402: 'Music', 9648: 'Mystery', 10749: 'Romance', 878: 'Science Fiction', 10770: 'TV Movie', 53: 'Thriller', 10752: 'War', 37: 'Western'}

mongoClient = pymongo.MongoClient("mongodb://localhost:27017/")
databaseName = mongoClient["themoviedb"]
cName = databaseName["movies"]
cName.delete_many({})
for i in range(1,250):
    end_point = 'https://api.themoviedb.org/3/discover/movie?api_key=5df612570394569437abc47e4534ad4e&language=en-US&page='+str(i)
    response = requests.get(end_point)
    if response.status_code == 200:
        responseData = json.loads(response.content.decode('utf-8'))
       
        data = responseData['results']
        for row in data:
            try:
                row['genre'] = gnr[row['genre_ids'][0]]
            except:
                row['genre'] = 'N/A'
            
            x = cName.insert_one(row) 
        print('Inserted 20 rows')
    else:
        print('API Failed')
# Out:
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows
# Inserted 20 rows

# %%
import pandas as pd

import pymongo


mongoClient = pymongo.MongoClient("mongodb://localhost:27017/")
databaseName = mongoClient["themoviedb"]
cName = databaseName["movies"]
allDocument = cName.find({})

df = pd.DataFrame(allDocument)
df['formated_date'] = pd.to_datetime(df['release_date'], errors='coerce')
df['year'] = df['formated_date'].dt.year
print(df.head(20))
# Out:
#                          _id  adult                     backdrop_path  \
# 0   6077824b8801cdf0e1151ba9  False  /inJjDhCjfhh3RtrJWBmmDqeuSYC.jpg
# 1   6077824b8801cdf0e1151baa  False  /pcDc2WJAYGJTTvRSEIpRZwM3Ola.jpg
# 2   6077824b8801cdf0e1151bab  False  /5NxjLfs7Bi07bfZCRl9CCnUw7AA.jpg
# 3   6077824b8801cdf0e1151bac  False  /hJuDvwzS0SPlsE6MNFOpznQltDZ.jpg
# 4   6077824b8801cdf0e1151bad  False  /fev8UFNFFYsD5q7AcYS8LyTzqwl.jpg
# 5   6077824b8801cdf0e1151bae  False  /z8TvnEVRenMSTemxYZwLGqFofgF.jpg
# 6   6077824b8801cdf0e1151baf  False  /uQtqiAu2bBlokqjlURVLEha6zoi.jpg
# 7   6077824b8801cdf0e1151bb0  False  /srYya1ZlI97Au4jUYAktDe3avyA.jpg
# 8   6077824b8801cdf0e1151bb1  False  /gzJnMEMkHowkUndn9gCr8ghQPzN.jpg
# 9   6077824b8801cdf0e1151bb2  False  /6TPZSJ06OEXeelx1U1VIAt0j9Ry.jpg
# 10  6077824b8801cdf0e1151bb3  False  /drulhSX7P5TQlEMQZ3JoXKSDEfz.jpg
# 11  6077824b8801cdf0e1151bb4  False  /9xeEGUZjgiKlI69jwIOi0hjKUIk.jpg
# 12  6077824b8801cdf0e1151bb5  False  /lOSdUkGQmbAl5JQ3QoHqBZUbZhC.jpg
# 13  6077824b8801cdf0e1151bb6  False  /jw0849O7WLarbYKJkA9WpRLeGKG.jpg
# 14  6077824b8801cdf0e1151bb7  False  /9Is9OrQUnKczCfsLSbsbx8YSmES.jpg
# 15  6077824b8801cdf0e1151bb8  False  /aMFl4wOPhJ7NVua6SgU9zIJvFSx.jpg
# 16  6077824b8801cdf0e1151bb9  False  /cjaOSjsjV6cl3uXdJqimktT880L.jpg
# 17  6077824b8801cdf0e1151bba  False  /fRrpOILyXuWaWLmqF7kXeMVwITQ.jpg
# 18  6077824b8801cdf0e1151bbb  False  /jnq4fV53Px9HvUZD2bQIxtGSwS7.jpg
# 19  6077824b8801cdf0e1151bbc  False  /vfuzELmhBjBTswXj2Vqxnu5ge4g.jpg
#
#                   genre_ids      id original_language  \
# 0                 [28, 878]  399566                en
# 1         [28, 12, 14, 878]  791373                en
# 2         [878, 28, 12, 53]  412656                en
# 3   [16, 12, 14, 10751, 28]  527774                en
# 4           [35, 10751, 16]  587807                en
# 5              [14, 28, 12]  458576                en
# 6                  [80, 18]  544401                en
# 7              [14, 28, 12]  464052                en
# 8              [53, 28, 18]  793723                fr
# 9              [28, 80, 53]  587996                es
# 10            [18, 14, 878]  581389                ko
# 11             [16, 28, 14]  664767                en
# 12        [53, 28, 878, 14]  775996                en
# 13              [35, 10749]  802504                nl
# 14             [16, 35, 14]  797394                ru
# 15              [16, 10751]  755812                fr
# 16      [10751, 14, 16, 35]  529203                en
# 17       [27, 53, 12, 9648]  522444                en
# 18             [80, 18, 28]  644083                en
# 19                 [53, 80]  602269                en
#
#                                original_title  \
# 0                           Godzilla vs. Kong
# 1                Zack Snyder's Justice League
# 2                               Chaos Walking
# 3                    Raya and the Last Dragon
# 4                                 Tom & Jerry
# 5                              Monster Hunter
# 6                                      Cherry
# 7                           Wonder Woman 1984
# 8                                  Sentinelle
# 9                                    Bajocero
# 10                                        승리호
# 11  Mortal Kombat Legends: Scorpion's Revenge
# 12                           Outside the Wire
# 13                               Just Say Yes
# 14         Ганзель, Гретель и Агентство Магии
# 15  Miraculous World: New York, United HeroeZ
# 16                      The Croods: A New Age
# 17                         Black Water: Abyss
# 18                                      Twist
# 19                          The Little Things
#
#                                              overview  popularity  \
# 0   In a time when monsters walk the Earth, humani...    6335.196
# 1   Determined to ensure Superman's ultimate sacri...    2996.489
# 2   Two unlikely companions embark on a perilous a...    2306.517
# 3   Long ago, in the fantasy world of Kumandra, hu...    1806.885
# 4   Tom the cat and Jerry the mouse get kicked out...    1200.698
# 5   A portal transports Cpt. Artemis and an elite ...    1127.229
# 6   Cherry drifts from college dropout to army med...    1118.438
# 7   A botched store robbery places Wonder Woman in...    1076.883
# 8   Transferred home after a traumatizing combat m...    1073.370
# 9   When a prisoner transfer van is attacked, the ...    1056.776
# 10  When the crew of a space junk collector ship c...     973.899
# 11  After the vicious slaughter of his family by s...     909.950
# 12  In the near future, a drone pilot is sent into...     855.296
# 13  Incurable romantic Lotte finds her life upende...     824.836
# 14  The Secret Magic Control Agency sends its two ...     795.432
# 15  During a school field trip, Ladybug and Cat No...     772.000
# 16  Searching for a safer habitat, the prehistoric...     743.078
# 17  An adventure-loving couple convince their frie...     717.580
# 18  A Dicken’s classic brought thrillingly up to d...     656.145
# 19  Deputy Sheriff Joe "Deke" Deacon joins forces ...     648.569
#
#                          poster_path release_date  \
# 0   /pgqgaUx1cJb5oZQQ5v0tNARCeBp.jpg   2021-03-24
# 1   /tnAuB8q5vv7Ax9UAEje5Xi4BXik.jpg   2021-03-18
# 2   /9kg73Mg8WJKlB9Y2SAJzeDKAnuB.jpg   2021-02-24
# 3   /lPsD10PP4rgUGiGR4CCXA6iY0QQ.jpg   2021-03-03
# 4   /6KErczPBROQty7QoIsaa6wJYXZi.jpg   2021-02-11
# 5   /1UCOF11QCw8kcqvce8LKOO6pimh.jpg   2020-12-03
# 6   /pwDvkDyaHEU9V7cApQhbcSJMG1w.jpg   2021-02-26
# 7   /8UlWHLMpgZm9bx6QYh0NFoq67TZ.jpg   2020-12-16
# 8   /fFRq98cW9lTo6di2o4lK1qUAWaN.jpg   2021-03-05
# 9   /dWSnsAGTfc8U27bWsy2RfwZs0Bs.jpg   2021-01-29
# 10  /bmemsraCG1kIthY74NjDnnLRT2Q.jpg   2021-02-05
# 11  /4VlXER3FImHeFuUjBShFamhIp9M.jpg   2020-04-12
# 12  /6XYLiMxHAaCsoyrVo38LBWMw2p8.jpg   2021-01-15
# 13  /3btDwus5VN5jOWfA9strpDJWwfj.jpg   2021-04-02
# 14  /4ZSzEDVdxWVMVO4oZDvoodQOEfr.jpg   2021-03-18
# 15  /kIHgjAkuzvKBnmdstpBOo4AfZah.jpg   2020-09-26
# 16  /tbVZ3Sq88dZaCANlUcewQuHQOaE.jpg   2020-11-25
# 17  /95S6PinQIvVe4uJAd82a2iGZ0rA.jpg   2020-07-09
# 18  /29dCusd9PwHrbDqzxNG35WcpZpS.jpg   2021-01-22
# 19  /c7VlGCCgM9GZivKSzBgzuOVxQn7.jpg   2021-01-28
#
#                                         title  video  vote_average  \
# 0                           Godzilla vs. Kong  False           8.4
# 1                Zack Snyder's Justice League  False           8.6
# 2                               Chaos Walking  False           7.4
# 3                    Raya and the Last Dragon  False           8.3
# 4                                 Tom & Jerry  False           7.3
# 5                              Monster Hunter  False           7.1
# 6                                      Cherry  False           7.6
# 7                           Wonder Woman 1984  False           6.8
# 8                                  Sentinelle  False           6.1
# 9                                  Below Zero  False           6.4
# 10                             Space Sweepers  False           7.2
# 11  Mortal Kombat Legends: Scorpion's Revenge  False           8.4
# 12                           Outside the Wire  False           6.5
# 13                               Just Say Yes  False           5.9
# 14                Secret Magic Control Agency  False           7.2
# 15  Miraculous World: New York, United HeroeZ  False           8.3
# 16                      The Croods: A New Age  False           7.5
# 17                         Black Water: Abyss  False           4.9
# 18                                      Twist  False           6.9
# 19                          The Little Things  False           6.4
#
#     vote_count            genre formated_date    year
# 0         4359           Action    2021-03-24  2021.0
# 1         4854           Action    2021-03-18  2021.0
# 2          334  Science Fiction    2021-02-24  2021.0
# 3         2252        Animation    2021-03-03  2021.0
# 4         1184           Comedy    2021-02-11  2021.0
# 5         1441          Fantasy    2020-12-03  2020.0
# 6          493            Crime    2021-02-26  2021.0
# 7         4813          Fantasy    2020-12-16  2020.0
# 8          331         Thriller    2021-03-05  2021.0
# 9          510           Action    2021-01-29  2021.0
# 10         491            Drama    2021-02-05  2021.0
# 11         837        Animation    2020-04-12  2020.0
# 12         978         Thriller    2021-01-15  2021.0
# 13          61           Comedy    2021-04-02  2021.0
# 14          91        Animation    2021-03-18  2021.0
# 15         621        Animation    2020-09-26  2020.0
# 16        1946           Family    2020-11-25  2020.0
# 17         189           Horror    2020-07-09  2020.0
# 18          34            Crime    2021-01-22  2021.0
# 19         740         Thriller    2021-01-28  2021.0

# %%
k= {'a':'a','b':'b'}
k['gener']='action'
print(k)
# Out:
# {'a': 'a', 'b': 'b', 'gener': 'action'}
